# %% [markdown]
# # STAT6309 HW1

# %% [markdown]
# ## Yichien Chou

# %% [markdown]
# ## <font color='green'>#3</font>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### (a)

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(filename= "/Users/jason13nn/Desktop/SMU/Spring 2020/STAT 6309 (Machine Learning)/files/picture.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-17df349270bf> in <module>
#       1 from IPython.display import Image
#       2 from IPython.core.display import HTML
# ----> 3 Image(filename= "/Users/jason13nn/Desktop/SMU/Spring 2020/STAT 6309 (Machine Learning)/files/picture.png")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1195         self.unconfined = unconfined
#    1196         super(Image, self).__init__(data=data, url=url, filename=filename,
# -> 1197                 metadata=metadata)
#    1198
#    1199         if self.width is None and self.metadata.get('width', {}):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
# ...

# %% [markdown]
# * `red` = test error
# * `orange` = estimator variance
# * `green` = model bias
# * `gray` = irreducible error
# * `blue` = train error

# %% [markdown]
# ### (b)
# •	Variance will increase with higher flexibility because changing data points will have more effect on the parameter estimates.
#
# •	Bias will decrease with higher flexibility because there are fewer assumptions made about the shape of the fit.
#
# •	Test error will have a U-shaped curve because it reflects the interaction between variance and bias.
#
# •	Irreducible error is the same regardless of model fit.
#
# •	Train error will always decrease with more model flexibility because an overfit model will produce lower MSE on the training data.

# %% [markdown]
# ## <font color='green'>#7</font>

# %% [markdown]
# ### (a)

# %%
import math

#observations
o1 = np.array([0, 3, 0])
o2 = np.array([2, 0, 0])
o3 = np.array([0, 1, 3])
o4 = np.array([0, 1, 2])
o5 = np.array([-1, 0, 1])
o6 = np.array([1, 1, 1])
o0 = np.array([0, 0, 0])

#Euclidean distance
print(math.sqrt(sum((o1-o0)**2)))
print(math.sqrt(sum((o2-o0)**2)))
print(math.sqrt(sum((o3-o0)**2)))
print(math.sqrt(sum((o4-o0)**2)))
print(math.sqrt(sum((o5-o0)**2)))
print(math.sqrt(sum((o6-o0)**2)))
# Out:
# 3.0
# 2.0
# 3.1622776601683795
# 2.23606797749979
# 1.4142135623730951
# 1.7320508075688772

# %% [markdown]
# ### (b)
# Our prediction is Green, because the closest 1 neighbor is 5th observation.

# %% [markdown]
# ### (c)
# Our prediction is Red, because the closest 3 neighbor is 5th, 6th, 2nd observation.

# %% [markdown]
# ### (d)
# The best value for K should be smaller if the Bayes boundary is highly non-linear.

# %% [markdown]
# ## <font color='green'>#8</font>

# %% [markdown]
# ### (a)

# %%
#read data
import pandas

College = pandas.read_csv('/Users/jason13nn/Desktop/SMU/Spring 2020/STAT 6309 (Machine Learning)/files/College.csv')

# %% [markdown]
# ### (b)

# %% [markdown]
# No need to do this process in Python.

# %% [markdown]
# ### (c)

# %% [markdown]
# ### i.

# %%
College.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# ### ii.

# %%
#Draw a scatter plot

import seaborn as sns

sns.set(style="ticks")
sns.pairplot(College.iloc[:,1:10])

# %% [markdown]
# ### iii.

# %%
#Draw a boxplot

sns.boxplot(data=College,x='Private',y='Outstate')

# %% [markdown]
# ### iv.

# %%
#Create new variable Ellite

def np_rep(x, repeat, length_out):
     return np.repeat(x, repeat)[:length_out]
    
Elite= np_rep('No', repeat = 777, length_out = 777)
Elite[College.Top10perc >50]="Yes"

#Frequent Table of Elite

freq = pandas.crosstab(index=Elite,  # Make a crosstab
                              columns="count")      # Name the count column

freq
# Out:
# col_0  count
# row_0
# No       699
# Ye        78

# %%
#Draw a boxplot

College['Elite']=Elite  #Add Elite into College

sns.boxplot(data=College,x='Elite',y='Outstate')

# %% [markdown]
# ### v.

# %%
#Draw histograms

plt.hist(College.Apps, bins='auto')
plt.title("Histogram with 'Apps'")

plt.show()

plt.hist(College.Enroll, bins='auto')
plt.title("Histogram with 'Enroll'")

plt.show()

plt.hist(College.Expend, bins='auto')
plt.title("Histogram with 'Expend'")

plt.show()

plt.hist(College.Outstate, bins='auto')
plt.title("Histogram with 'Outstate'")

plt.show()

# %% [markdown]
# ### vi.

# %%
#Boxplot

sns.boxplot(data=College,x='Private',y='Top10perc')

# %% [markdown]
# From the boxplot, we can find that the percentage of freshmen from top 10% of H.S. class in private universities is higher than that of public universities.

# %% [markdown]
# ## <font color='green'>#9</font>

# %%
#read data

Auto=pandas.read_csv('/Users/jason13nn/Desktop/SMU/Spring 2020/STAT 6309 (Machine Learning)/files/Auto.csv')

# %% [markdown]
# ### (a)

# %% [markdown]
# #### Quantitatives:
# mpg, cylinders, displacement, horsepower, weight, acceleration, year.
#
# #### Qualitative variables:
# origin, name.

# %% [markdown]
# ### (b)

# %%
#Find ranges of quantitative predictors

#Create range function

def range(variable):
    return max(variable)-min(variable)

range(Auto.mpg)
# Out:
# 37.6

# %%
range(Auto.cylinders)
# Out:
# 5

# %%
range(Auto.displacement)
# Out:
# 387.0

# %%
range(Auto.horsepower)
# Out:
# 184

# %%
range(Auto.weight)
# Out:
# 3527

# %%
range(Auto.acceleration)
# Out:
# 16.8

# %%
range(Auto.year)
# Out:
# 12

# %% [markdown]
# ### (c)

# %%
#Find mean and standard deviation
import statistics as st

def ms(variable):
    return st.mean(variable), st.stdev(variable)

# %%
ms(Auto.mpg)
# Out:
# (23.445918367346938, 7.805007486571799)

# %%
ms(Auto.cylinders)
# Out:
# (5.471938775510204, 1.7057832474527848)

# %%
ms(Auto.displacement)
# Out:
# (194.41198979591837, 104.64400390890465)

# %%
ms(Auto.horsepower)
# Out:
# (104.46938775510205, 38.49115993282849)

# %%
ms(Auto.weight)
# Out:
# (2977.5841836734694, 849.4025600429493)

# %%
ms(Auto.acceleration)
# Out:
# (15.541326530612245, 2.758864119188082)

# %%
ms(Auto.year)
# Out:
# (75.9795918367347, 3.6837365435778295)

# %% [markdown]
# ### (d)

# %%
#Drop 10th to 85th observations

Auto1=Auto.drop([9,84],axis = 0)

#Find mean and standard deviation

ms(Auto1.mpg)
# Out:
# (23.494358974358974, 7.795197847726639)

# %%
ms(Auto1.cylinders)
# Out:
# (5.458974358974359, 1.7004789811719772)

# %%
ms(Auto1.displacement)
# Out:
# (193.51153846153846, 104.14068986493602)

# %%
ms(Auto1.horsepower)
# Out:
# (104.06923076923077, 38.176330530505055)

# %%
ms(Auto1.weight)
# Out:
# (2972.4692307692308, 848.5120669988108)

# %%
ms(Auto1.acceleration)
# Out:
# (15.565897435897435, 2.7396716238301524)

# %%
ms(Auto1.year)
# Out:
# (76.00256410256411, 3.6775555743329065)

# %% [markdown]
# ### (e)

# %%
#Draw a scatterplot
sns.set(style="ticks")
sns.pairplot(College.iloc[:,1:7])

# %% [markdown]
# `mpg` is negatively correlated with `cylinders`, `displacement`, `horsepower`, and `weight`.
#
# `displacement` is positively correlated with `horsepower` and `weight`, negatively correlated with `acceleration`.
#
# `horsepower` is negatively correlated with `weight`, negatively correlated with `acceleration`.

# %% [markdown]
# ### (f)

# %% [markdown]
# From the scatterplot, we can see that cylinders, displacement, horsepower, and weight have relationships between mpg.

# %% [markdown]
# ## <font color='green'>#10</font>
# ### (a)

# %%
#read data

Boston=pandas.read_csv('/Users/jason13nn/Desktop/SMU/Spring 2020/STAT 6309 (Machine Learning)/files/Boston.csv')

# %% [markdown]
# #The Boston data frame has 506 rows and 14 columns.
#
# #Source: Harrison, D. and Rubinfeld, D.L. (1978) Hedonic prices and the demand for clean air. J. Environ. Economics and Management 5, 81–102. Belsley D.A., Kuh, E. and Welsch, R.E. (1980) Regression Diagnostics. Identifying Influential Data and Sources of Collinearity. New York: Wiley.

# %% [markdown]
# ### (b)

# %%
#Draw a scatterplot
sns.set(style="ticks")
sns.pairplot(Boston.iloc[:,])

# %% [markdown]
# There seems no linear relationship between crime rate per capita and any other variables in the dataset.

# %% [markdown]
# ### (c)

# %%
#Correlation Matrix

corr = Boston.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %% [markdown]
# From the scatterplot, we can see that crime rate per capita has some correlations with most of variables, except chas.

# %% [markdown]
# ### (d)

# %%
#Scatterplots

x=np.arange(0,506)

plt.scatter(x, y=Boston.crim)
plt.xlabel('')
plt.ylabel('Crime Rate per Capita')
plt.show()

# %%
plt.scatter(x, y=Boston.tax)
plt.xlabel('')
plt.ylabel('Tax rates')
plt.show()

# %%
plt.scatter(x, y=Boston.ptratio)
plt.xlabel('')
plt.ylabel('Pupil-teacher ratios')
plt.show()

# %% [markdown]
# There are outliers in variable `crim` and `tax`.

# %% [markdown]
# ### (e)

# %%
#Frequent Table of chas

freq = pandas.crosstab(index=Boston.chas,  # Make a crosstab
                             columns="count")      # Name the count column

freq


#len(College.Elite==true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3db60463e606> in <module>
#       1 #Frequent Table of chas
#       2
# ----> 3 freq = pandas.crosstab(index=Boston.chas,  # Make a crosstab
#       4                               columns="count")      # Name the count column
#       5
#
# NameError: name 'pandas' is not defined

# %% [markdown]
# ### (f)

# %%
#Median of pupil-teacher ratio by town.

st.median(Boston.ptratio)
# Out:
# 19.05

# %% [markdown]
# ### (g)

# %%
low_med= Boston[Boston.medv == min(Boston.medv)]
low_med
#The lowest medv value of suburb is 5.
#There are two towns have same lowerest medv value.
# Out:
#      Unnamed: 0     crim   zn  indus  chas    nox     rm    age     dis  rad  \
# 398         399  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24
# 405         406  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24
#
#      tax  ptratio   black  lstat  medv
# 398  666     20.2  396.90  30.59   5.0
# 405  666     20.2  384.97  22.98   5.0

# %%
# overall quartiles of predictors

Boston.quantile([0.25,0.5,0.75])
# Out:
#       Unnamed: 0      crim    zn  indus  chas    nox      rm     age  \
# 0.25      127.25  0.082045   0.0   5.19   0.0  0.449  5.8855  45.025
# 0.50      253.50  0.256510   0.0   9.69   0.0  0.538  6.2085  77.500
# 0.75      379.75  3.677082  12.5  18.10   0.0  0.624  6.6235  94.075
#
#            dis   rad    tax  ptratio     black   lstat    medv
# 0.25  2.100175   4.0  279.0    17.40  375.3775   6.950  17.025
# 0.50  3.207450   5.0  330.0    19.05  391.4400  11.360  21.200
# 0.75  5.188425  24.0  666.0    20.20  396.2250  16.955  25.000

# %% [markdown]
# * `age`, `rad` at max
# * `crim`, `indus`, `nox`, `tax`, `ptratio`, `lstat` at or above 75th percentile
# * low for `zn`, `rm`, `dis`

# %% [markdown]
# ### (h)

# %%
sum(1 for n in Boston.rm if n>7)  # 64 suburbs average more than 7 rooms per dwelling.
# Out:
# 64

# %%
sum(1 for n in Boston.rm if n>8)  # 13 suburbs average more than 8 rooms per dwelling.
# Out:
# 13

# %%
#For the mean of overall

Boston.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677082   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
#For the mean of room more than 8

Boston1=Boston[Boston.rm>8]

Boston1.describe()
# Out:
#        Unnamed: 0       crim         zn      indus       chas        nox  \
# count   13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean   232.307692   0.718795  13.615385   7.078462   0.153846   0.539238
# std     60.915768   0.901640  26.298094   5.392767   0.375534   0.092352
# min     98.000000   0.020090   0.000000   2.680000   0.000000   0.416100
# 25%    225.000000   0.331470   0.000000   3.970000   0.000000   0.504000
# 50%    233.000000   0.520140   0.000000   6.200000   0.000000   0.507000
# 75%    258.000000   0.578340  20.000000   6.200000   0.000000   0.605000
# max    365.000000   3.474280  95.000000  19.580000   1.000000   0.718000
#
#               rm        age        dis        rad         tax    ptratio  \
# count  13.000000  13.000000  13.000000  13.000000   13.000000  13.000000
# mean    8.348538  71.538462   3.430192   7.461538  325.076923  16.361538
# std     0.251261  24.608723   1.883955   5.332532  110.971063   2.410580
# ...

# %% [markdown]
# * The crim rates are lower than the overall average.
# * Lower proportion of non-retail business acres per town.
# *Lower full-value property-tax rate.
# *Much lower for lower status of the population.
# *Much higher median value of owner-occupied homes in \$1000s.
